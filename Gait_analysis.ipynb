# %%
import os
import pandas as pd
import numpy as np
from gaitpy.gait import Gaitpy

# %% [markdown]
# # Gaitpy Demo Code

# %%
df = pd.read_csv('demo_data.csv', skiprows=99, names=['timestamps', 'x', 'y', 'z'], usecols=[0,1,2,3])
df['unix_timestamps'] = pd.to_datetime(df.timestamps, format="%Y-%m-%d %H:%M:%S:%f").values.astype(np.int64) // 10**6
df.to_csv("demo_filtered.csv")

# %%
# Algo
from gaitpy.gait import Gaitpy

raw_data = 'demo_filtered.csv'
sample_rate = 50 # hertz
subject_height = 177 # centimeters

#### Create an instance of Gaitpy ####
gaitpy = Gaitpy(raw_data,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

# %%
gait_bouts = gaitpy.classify_bouts(result_file="classify_bouts.h5")
# Out:
# 	Classifying bouts of gait...
# 	Bout classification complete!

# %%
#### Extract gait characteristics ####
gait_features = gaitpy.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts)
# Out:
# 	Extracting features...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2019-08-06 10:25:59.500000 and 2019-08-06 10:26:02.500000, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# 	Feature extraction complete!

# %%
#### Plot results of gait feature extraction ####
gaitpy.plot_contacts(gait_features,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts.html)',      # File to save results to (None by default)
                     show_plot=True)
# Out:
# 	Plotting contacts...
# 	Plot complete!

# %% [markdown]
# # Test with Gideon's Data

# %%
#### TEST GIDEON DATA
import pandas as pd
import numpy as np
import os
acti_data = "actigraph_test/Gideon (2021-07-13)30secDataTable.csv"
gideon_df = pd.read_csv(acti_data, skiprows=10, header=0, usecols=[0,1,2,3,4])
gideon_df['timestamp'] = gideon_df['Date'] + '-' + gideon_df['Time']
gideon_df = gideon_df.rename(columns={'Axis1':'x','Axis2':'y','Axis3':'z'})
gideon_df['unix_timestamps'] = pd.to_datetime(gideon_df.timestamp, format="%m/%d/%Y-%H:%M:%S").values.astype(np.int64) // 10**6
gideon_df_filtered = gideon_df.drop(['Date','Time'], axis=1)
gideon_df_filtered.to_csv("Gideon_2021-07-13_30secWaist_filtered.csv")

# %%
raw_data = 'Gideon_2021-07-13_30secWaist_filtered.csv'
sample_rate = 50 # hertz
subject_height = 167 # centimeters

#### Create an instance of Gaitpy ####
gaitpy = Gaitpy(raw_data,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

# %%
gait_bouts = gaitpy.classify_bouts(result_file="gideon_30secWaist_classify_bouts.h5")
# Out:
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1525200 and 1525350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1525350 and 1525500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1526550 and 1526700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1526700 and 1526850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1526850 and 1527000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1528200 and 1528350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1528350 and 1528500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1528500 and 1528650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1529550 and 1529700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1529700 and 1529850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1529850 and 1530000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1531200 and 1531350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1531350 and 1531500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1532700 and 1532850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1532850 and 1533000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1533000 and 1533150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1534050 and 1534200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1534200 and 1534350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1534350 and 1534500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1535700 and 1535850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1535850 and 1536000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1536000 and 1536150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1537050 and 1537200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1537200 and 1537350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1537350 and 1537500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1538700 and 1538850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1538850 and 1539000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1540200 and 1540350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1540350 and 1540500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1540500 and 1540650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1541550 and 1541700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1541700 and 1541850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1541850 and 1542000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1543200 and 1543350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1543350 and 1543500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1544700 and 1544850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1544850 and 1545000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1546050 and 1546200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1546200 and 1546350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1546350 and 1546500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1547700 and 1547850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1547850 and 1548000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1549200 and 1549350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1549350 and 1549500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1550700 and 1550850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1550850 and 1551000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1558200 and 1558350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1558350 and 1558500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1559700 and 1559850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1559850 and 1560000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1560000 and 1560150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1561200 and 1561350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1561350 and 1561500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1562700 and 1562850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1562850 and 1563000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1564200 and 1564350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1564350 and 1564500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1565700 and 1565850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1565850 and 1566000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:353: UserWarning: Error calculating signal features for 3-second window between 1569750 and 1569900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1569900 and 1570050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570050 and 1570200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570200 and 1570350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570350 and 1570500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570500 and 1570650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570650 and 1570800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570800 and 1570950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1570950 and 1571100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571100 and 1571250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571250 and 1571400, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571400 and 1571550, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571550 and 1571700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571700 and 1571850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1571850 and 1572000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572000 and 1572150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572150 and 1572300, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572300 and 1572450, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572450 and 1572600, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572600 and 1572750, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572750 and 1572900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1572900 and 1573050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573050 and 1573200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573200 and 1573350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573350 and 1573500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573500 and 1573650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573650 and 1573800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573800 and 1573950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1573950 and 1574100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574100 and 1574250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574250 and 1574400, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574400 and 1574550, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574550 and 1574700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574700 and 1574850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1574850 and 1575000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575000 and 1575150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575150 and 1575300, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575300 and 1575450, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575450 and 1575600, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575600 and 1575750, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575750 and 1575900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1575900 and 1576050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576050 and 1576200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576200 and 1576350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576350 and 1576500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576500 and 1576650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576650 and 1576800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576800 and 1576950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1576950 and 1577100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577100 and 1577250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577250 and 1577400, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577400 and 1577550, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577550 and 1577700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577700 and 1577850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1577850 and 1578000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578000 and 1578150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578150 and 1578300, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578300 and 1578450, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578450 and 1578600, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578600 and 1578750, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578750 and 1578900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1578900 and 1579050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579050 and 1579200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579200 and 1579350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579350 and 1579500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579500 and 1579650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579650 and 1579800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579800 and 1579950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1579950 and 1580100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:353: UserWarning: Error calculating signal features for 3-second window between 1580100 and 1580250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 1583700 and 1583850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# ...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422050 and 2422200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422200 and 2422350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422350 and 2422500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422500 and 2422650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422650 and 2422800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422800 and 2422950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2422950 and 2423100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423100 and 2423250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423250 and 2423400, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423400 and 2423550, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423550 and 2423700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423700 and 2423850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2423850 and 2424000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424000 and 2424150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424150 and 2424300, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424300 and 2424450, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424450 and 2424600, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424600 and 2424750, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424750 and 2424900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2424900 and 2425050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425050 and 2425200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425200 and 2425350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425350 and 2425500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425500 and 2425650, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425650 and 2425800, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425800 and 2425950, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2425950 and 2426100, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426100 and 2426250, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426250 and 2426400, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426400 and 2426550, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426550 and 2426700, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426700 and 2426850, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2426850 and 2427000, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427000 and 2427150, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427150 and 2427300, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427300 and 2427450, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# 	Bout classification complete!
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427450 and 2427600, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427600 and 2427750, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427750 and 2427900, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2427900 and 2428050, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2428050 and 2428200, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2428200 and 2428350, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:348: UserWarning: Error calculating signal features for 3-second window between 2428350 and 2428500, skipping window...
#   warnings.warn('Error calculating signal features for 3-second window between '+str(current_win_start)+' and '+str(current_win_end)+', skipping window...')

# %%
#### Extract gait characteristics ####
gait_features = gaitpy.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='gideon_30secWaist_gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts)
# Out:
# 	Extracting features...
# The classified_gait data indicates no bouts of gait were detected, aborting...

# %%
#### Plot results of gait feature extraction ####
gaitpy.plot_contacts(gait_features,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='gideon_30secWaist_plot_contacts.html)',      # File to save results to (None by default)
                     show_plot=True)

# %% [markdown]
# # Test with Dwight Data

# %%
#### TEST DWIGHT DATA
import pandas as pd
import numpy as np
import os
acti_data = "actigraph_test/dwight_ankle30hz.csv"
dwight_df = pd.read_csv(acti_data, header=0, usecols=[0,1,2,3])
dwight_df.to_csv("dwight_ankle30hz_filtered.csv")

# %%
# Algo
from gaitpy.gait import Gaitpy

raw_data = 'dwight_ankle30hz_filtered.csv'
sample_rate = 50 # hertz
subject_height = 170 # centimeters

#### Create an instance of Gaitpy ####
gaitpy_dw = Gaitpy(raw_data,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

# %%
gait_bouts_dw = gaitpy_dw.classify_bouts(result_file="dwight_classify_bouts.h5")
# Out:
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!

# %%
#### Extract gait characteristics ####
gait_features_dw = gaitpy_dw.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='dwight_gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_dw)
# Out:
# 	Extracting features...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:00:06 and 2021-09-30 00:00:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:00:12 and 2021-09-30 00:00:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:00:39 and 2021-09-30 00:00:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:00:45 and 2021-09-30 00:00:48, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:00:51 and 2021-09-30 00:01:00, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:01:15 and 2021-09-30 00:01:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:01:33 and 2021-09-30 00:01:36, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:01:39 and 2021-09-30 00:01:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:02:18 and 2021-09-30 00:02:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:02:36 and 2021-09-30 00:02:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:02:45 and 2021-09-30 00:02:51, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:03:03 and 2021-09-30 00:16:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:16:45 and 2021-09-30 00:16:51, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:24:03 and 2021-09-30 00:24:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:24:15 and 2021-09-30 00:24:18, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# 	Feature extraction complete!
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-09-30 00:24:36 and 2021-09-30 00:24:39, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')

# %%
#### Plot results of gait feature extraction ####
gaitpy_dw.plot_contacts(gait_features_dw,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts.html',      # File to save results to (None by default)
                     show_plot=True)
# Out:
# 	Plotting contacts...
# 	Plot complete!

# %% [markdown]
# # Actigraph Data Pre-processing
# Extract relevant accelerometer data, generate unix timestamps

# %%
################################################### DWIGHT DATA ##############################################################

## Load data
ankle_raw_path = os.path.join("dwight-data","TAS1F51160037 (2021-11-21)-IMU-Back-waist.csv")
waist_raw_path = os.path.join("dwight-data","TAS1H17210028 (2021-11-21)-IMU-Ankle.csv")
ankle_raw_df = pd.read_csv(ankle_raw_path, skiprows=11, names=['timestamps', 'x', 'y', 'z'], usecols=[0,1,2,3])
waist_raw_df = pd.read_csv(waist_raw_path, skiprows=11, names=['timestamps', 'x', 'y', 'z'], usecols=[0,1,2,3])
## Add unix timestamps
ankle_raw_df['unix_timestamps'] = pd.to_datetime(ankle_raw_df.timestamps, format="%Y-%m-%dT%H:%M:%S.%f").values.astype(np.int64) // 10**6
waist_raw_df['unix_timestamps'] = pd.to_datetime(waist_raw_df.timestamps, format="%Y-%m-%dT%H:%M:%S.%f").values.astype(np.int64) // 10**6
# Save results to CSV
path_ankle = os.path.join('dwight-data',"dwight_ankle100hz_2021-11-21.csv")
path_waist = os.path.join('dwight-data',"dwight_waist100hz_2021-11-21.csv")
ankle_raw_df.to_csv(path_ankle,index=False)
waist_raw_df.to_csv(path_waist,index=False)

# %% [markdown]
# # Run Gaitpy Analysis on Processed Actigraph Data

# %%
# Algo
from gaitpy.gait import Gaitpy

#os.chdir("dwight-data")
ankle = 'sam_ankle100hz_2022-03-11_filtered.csv'
waist = 'sam_waist100hz_2022-03-11_filtered.csv'
ankle_name = 'sam_ankle100hz_2022-03-11'
waist_name = 'sam_waist100hz_2022-03-11'
sample_rate = 100 # hertz
subject_height = 180 # centimeters

#### Create an instance of Gaitpy ####
gaitpy_ankle = Gaitpy(ankle,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='accel_y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

gaitpy_waist = Gaitpy(waist,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='accel_y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

#### Classify bouts
gait_bouts_ankle = gaitpy_ankle.classify_bouts(result_file=f"{ankle_name}_classify_bouts.h5")
gait_bouts_waist = gaitpy_waist.classify_bouts(result_file=f"{waist_name}_classify_bouts.h5")


#### Extract gait characteristics ####
gait_features_ankle = gaitpy_ankle.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file=f'{ankle_name}_gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_ankle)
gait_features_waist = gaitpy_waist.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file=f'{waist_name}_gait_features.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_waist)

#### Plot results of gait feature extraction ####
gaitpy_ankle.plot_contacts(gait_features_ankle,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file=f'{ankle_name}_plot_contacts.html',      # File to save results to (None by default)
                     show_plot=True)
gaitpy_waist.plot_contacts(gait_features_waist,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file=f'{waist_name}_plot_contacts.html',      # File to save results to (None by default)
                     show_plot=True)
# Out:
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Extracting features...
# 	Feature extraction complete!
#
# 	Extracting features...
# 	Feature extraction complete!
#
# 	Plotting contacts...
# 	Plot complete!
#
# 	Plotting contacts...
# 	Plot complete!

# %% [markdown]
# # Dwight Data Analysis

# %%
# Algo
from gaitpy.gait import Gaitpy

os.chdir("dwight-data")
ankle_dwight = 'dwight_ankle100hz_2021-11-21.csv'
waist_dwight = 'dwight_waist100hz_2021-11-21.csv'
sample_rate = 100 # hertz
subject_height = 183 # centimeters

#### Create an instance of Gaitpy ####
gaitpy_dw_ankle = Gaitpy(ankle_dwight,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

gaitpy_dw_waist = Gaitpy(waist_dwight,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='y',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

#### Classify bouts
gait_bouts_dw_ankle = gaitpy_dw_ankle.classify_bouts(result_file="dwight_classify_bouts_ankle-2021-11-21.h5")
gait_bouts_dw_waist = gaitpy_dw_waist.classify_bouts(result_file="dwight_classify_bouts_waist-2021-11-21.h5")


#### Extract gait characteristics ####
gait_features_dw_ankle = gaitpy_dw_ankle.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='dwight_gait_features_ankle-2021-11-21.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_dw_ankle)
gait_features_dw_waist = gaitpy_dw_waist.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='dwight_gait_features_waist-2021-11-21.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_dw_waist)

#### Plot results of gait feature extraction ####
gaitpy_dw_ankle.plot_contacts(gait_features_dw_ankle,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts_ankle-2021-11-21.html',      # File to save results to (None by default)
                     show_plot=True)
gaitpy_dw_waist.plot_contacts(gait_features_dw_waist,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts_waist-2021-11-21.html',      # File to save results to (None by default)
                     show_plot=True)
# Out:
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Extracting features...
# 	Feature extraction complete!
#
# 	Extracting features...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:29:06 and 2021-11-21 18:29:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:32:09 and 2021-11-21 18:32:12, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:12 and 2021-11-21 18:33:15, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:54 and 2021-11-21 18:33:57, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:06 and 2021-11-21 18:34:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:24 and 2021-11-21 18:34:27, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:45 and 2021-11-21 18:34:48, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:51 and 2021-11-21 18:34:54, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:00 and 2021-11-21 18:35:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:12 and 2021-11-21 18:35:15, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:09 and 2021-11-21 18:36:12, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:45 and 2021-11-21 18:36:48, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:57 and 2021-11-21 18:37:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:37:36 and 2021-11-21 18:37:39, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:00 and 2021-11-21 18:38:03, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:21 and 2021-11-21 18:38:24, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:27 and 2021-11-21 18:38:30, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:36 and 2021-11-21 18:38:39, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:03 and 2021-11-21 18:39:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:18 and 2021-11-21 18:39:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:33 and 2021-11-21 18:39:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:40:21 and 2021-11-21 18:40:24, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# 	Feature extraction complete!
#
# 	Plotting contacts...
# 	Plot complete!
#
# 	Plotting contacts...
# 	Plot complete!

# %% [markdown]
# # Gyro Data Analysis
# ## NOTE: This workflow was not intended for gyroscope data, so results are almost certainly inaccurate

# %%
#### FOR GYRO ANALYSIS
## Load data
ankle_raw_path = os.path.join("dwight-data","TAS1F51160037 (2021-11-19)-IMU-Back-waist.csv")
waist_raw_path = os.path.join("dwight-data","TAS1H17210028 (2021-11-19)-IMU-Ankle.csv")
ankle_raw_df = pd.read_csv(ankle_raw_path, skiprows=11, names=['timestamps', 'gyro_x', 'gyro_y', 'gyro_z'], usecols=[0,4,5,6])
waist_raw_df = pd.read_csv(waist_raw_path, skiprows=11, names=['timestamps', 'gyro_x', 'gyro_y', 'gyro_z'], usecols=[0,4,5,6])
## Add unix timestamps
ankle_raw_df['unix_timestamps'] = pd.to_datetime(ankle_raw_df.timestamps, format="%Y-%m-%dT%H:%M:%S.%f").values.astype(np.int64) // 10**6
waist_raw_df['unix_timestamps'] = pd.to_datetime(waist_raw_df.timestamps, format="%Y-%m-%dT%H:%M:%S.%f").values.astype(np.int64) // 10**6
# Save results to CSV
path_ankle = os.path.join('dwight-data',"dwight_ankle100hz_GYRO_2021-11-19.csv")
path_waist = os.path.join('dwight-data',"dwight_waist100hz_GYRO_2021-11-19.csv")
ankle_raw_df.to_csv(path_ankle,index=False)
waist_raw_df.to_csv(path_waist,index=False)

# %%
# Algo
from gaitpy.gait import Gaitpy

#os.chdir("dwight-data")
ankle_dwight = 'dwight_ankle100hz_GYRO_2021-11-21.csv'
waist_dwight = 'dwight_waist100hz_GYRO_2021-11-21.csv'
sample_rate = 100 # hertz
subject_height = 183 # centimeters

#### Create an instance of Gaitpy ####
gaitpy_dw_ankle = Gaitpy(ankle_dwight,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='gyro_z',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

gaitpy_dw_waist = Gaitpy(waist_dwight,                           # Raw data consisting of vertical acceleration from lumbar location and unix timestamps
                sample_rate,                        # Sample rate of raw data (in Hertz)
                v_acc_col_name='gyro_z',                 # Vertical acceleration column name
                ts_col_name='unix_timestamps',           # Timestamp column name
                v_acc_units='g',                # Units of vertical acceleration
                ts_units='ms',                       # Units of timestamps
                flip=False)                         # If baseline data is at +1g or +9.8m/s^2, set flip=True

#### Classify bouts
gait_bouts_dw_ankle = gaitpy_dw_ankle.classify_bouts(result_file="dwight_classify_bouts_ankle_GYROZ-2021-11-21.h5")
gait_bouts_dw_waist = gaitpy_dw_waist.classify_bouts(result_file="dwight_classify_bouts_waist_GYROZ-2021-11-21.h5")


#### Extract gait characteristics ####
gait_features_dw_ankle = gaitpy_dw_ankle.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='dwight_gait_features_ankle_GYROZ-2021-11-21.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_dw_ankle)
gait_features_dw_waist = gaitpy_dw_waist.extract_features(subject_height,                               # Subject height
                                        subject_height_units='centimeter',            # Units of subject height
                                        result_file='dwight_gait_features_waist_GYROZ-2021-11-21.csv',   # File to save results to (None by default)
                                        classified_gait=gait_bouts_dw_waist)

#### Plot results of gait feature extraction ####
gaitpy_dw_ankle.plot_contacts(gait_features_dw_ankle,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts_ankle_GYROZ-2021-11-21.html',      # File to save results to (None by default)
                     show_plot=True)
gaitpy_dw_waist.plot_contacts(gait_features_dw_waist,                                     # Pandas Dataframe or .csv file results of extract_features function
                     result_file='plot_contacts_waist_GYROZ-2021-11-21.html',      # File to save results to (None by default)
                     show_plot=True)
# Out:
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Classifying bouts of gait...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.18.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 	Bout classification complete!
#
# 	Extracting features...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:30:00 and 2021-11-21 18:30:03, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:30:12 and 2021-11-21 18:30:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:30:27 and 2021-11-21 18:30:30, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\util.py:155: RuntimeWarning: invalid value encountered in sqrt
#   cwt_features.loc[cwt_features['Gait_Cycle'] == 1, 'step_length'] = 2*(np.sqrt((2*sensor_height*cwt_features.CoM_height)-(cwt_features.CoM_height**2)))
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:31:30 and 2021-11-21 18:31:33, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:31:36 and 2021-11-21 18:31:39, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:31:48 and 2021-11-21 18:31:51, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:32:06 and 2021-11-21 18:32:15, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:32:18 and 2021-11-21 18:32:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:32:24 and 2021-11-21 18:32:33, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:32:39 and 2021-11-21 18:32:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:00 and 2021-11-21 18:33:06, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:09 and 2021-11-21 18:33:18, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:21 and 2021-11-21 18:33:30, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:33:48 and 2021-11-21 18:34:00, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:18 and 2021-11-21 18:34:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:24 and 2021-11-21 18:34:33, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:51 and 2021-11-21 18:34:57, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:03 and 2021-11-21 18:35:12, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:24 and 2021-11-21 18:35:30, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:33 and 2021-11-21 18:35:36, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:39 and 2021-11-21 18:35:42, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:45 and 2021-11-21 18:35:48, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:35:57 and 2021-11-21 18:36:00, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:09 and 2021-11-21 18:36:12, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:33 and 2021-11-21 18:36:36, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:42 and 2021-11-21 18:36:45, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:36:54 and 2021-11-21 18:36:57, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:37:03 and 2021-11-21 18:37:12, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:12 and 2021-11-21 18:38:15, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:21 and 2021-11-21 18:38:24, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:39 and 2021-11-21 18:38:48, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:27 and 2021-11-21 18:39:33, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:51 and 2021-11-21 18:39:57, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# 	Feature extraction complete!
#
# 	Extracting features...
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:29:06 and 2021-11-21 18:29:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:29:12 and 2021-11-21 18:29:18, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:30:00 and 2021-11-21 18:30:06, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:30:12 and 2021-11-21 18:30:18, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:34:57 and 2021-11-21 18:35:00, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:37:09 and 2021-11-21 18:37:21, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:38:27 and 2021-11-21 18:38:30, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:39:57 and 2021-11-21 18:40:00, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:40:09 and 2021-11-21 18:40:15, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:40:21 and 2021-11-21 18:40:27, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# d:\evgeni\conda_environments\gaitpy\lib\site-packages\gaitpy-1.6.1-py3.6.egg\gaitpy\gait.py:149: UserWarning: Data appears to be flipped between 2021-11-21 18:41:06 and 2021-11-21 18:41:09, flipping axis...
#   warnings.warn('Data appears to be flipped between '+str(bout.start_time)+' and '+str(bout.end_time)+', flipping axis...')
# 	Feature extraction complete!
#
# 	Plotting contacts...
# 	Plot complete!
#
# 	Plotting contacts...
# 	Plot complete!
